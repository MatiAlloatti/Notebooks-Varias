# %%
from fastai.vision import *
from fastai import *
from fastai.widgets import *
import glob, os, fnmatch
root_dir = "/storage/notebooks/"
base_dir = root_dir + 'Bears/Data'
path = Path(base_dir)
path_test=Path(root_dir + 'Bears/test_set')
# classes = ['teddy','grizzly','black','polar','panda']
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
learn.load('stage-1');

# %%
imgN = input("Nombre de la imagen: ") 
img = open_image(path_test/imgN)
pred_class,pred_idx,outputs = learn.predict(img)
print(pred_class)
# Out:
# Nombre de la imagen: gera2.jpeg
# teddy

# %%
for file in os.listdir(path_test):
    if fnmatch.fnmatch(file, '*.jpg'):
        print(file)
        img = open_image(path_test/file)
        pred_class,pred_idx,outputs = learn.predict(img)
        print(pred_class, pred_idx,outputs,'\n')
# Out:
# 00000123.jpg
# panda tensor(2) tensor([1.2057e-04, 3.2974e-06, 9.9840e-01, 8.0054e-06, 1.4724e-03])
#
# 00000190.jpg
# panda tensor(2) tensor([4.5188e-05, 2.3568e-05, 5.9589e-01, 9.3019e-07, 4.0404e-01])
#
# 00000193.jpg
# polar tensor(3) tensor([1.8272e-03, 4.6498e-02, 2.0579e-05, 9.5162e-01, 3.6713e-05])
#
# 00000089.jpg
# black tensor(0) tensor([9.9752e-01, 2.6250e-04, 2.4142e-04, 2.1789e-06, 1.9697e-03])
#
# 00000125.jpg
# black tensor(0) tensor([9.8855e-01, 1.1261e-02, 1.7736e-04, 4.4255e-06, 1.2299e-05])
#
# 00000068.jpg
# polar tensor(3) tensor([1.8448e-06, 1.5869e-04, 2.0528e-04, 9.9963e-01, 7.8070e-08])
#
# 00000100.jpg
# polar tensor(3) tensor([0.0014, 0.0036, 0.2037, 0.4841, 0.3072])
#
# 00000074.jpg
# grizzly tensor(1) tensor([4.2109e-05, 9.9995e-01, 6.8028e-09, 8.2072e-06, 8.0507e-07])
#
# 00000065.jpg
# grizzly tensor(1) tensor([2.8200e-03, 9.9531e-01, 5.9713e-07, 1.5857e-03, 2.8601e-04])
#
# 00000182.jpg
# teddy tensor(4) tensor([5.2863e-05, 8.6522e-05, 9.9104e-06, 2.6888e-05, 9.9982e-01])
#
# 00000021.jpg
# grizzly tensor(1) tensor([7.2740e-06, 9.9999e-01, 1.0293e-08, 4.9881e-08, 3.7370e-07])
#
# 00000151.jpg
# panda tensor(2) tensor([0.0390, 0.3095, 0.6391, 0.0106, 0.0019])
#
# 00000161.jpg
# panda tensor(2) tensor([1.9329e-01, 1.6387e-01, 6.4146e-01, 2.4666e-04, 1.1277e-03])
#
# 00000042.jpg
# black tensor(0) tensor([9.8714e-01, 3.5678e-03, 9.2291e-03, 2.7303e-06, 5.8474e-05])
#
# 00000136.jpg
# grizzly tensor(1) tensor([5.9492e-05, 9.9929e-01, 2.8441e-05, 1.2124e-05, 6.0719e-04])
#
# 00000149.jpg
# grizzly tensor(1) tensor([0.0556, 0.8004, 0.0842, 0.0213, 0.0385])
#
# 00000116.jpg
# grizzly tensor(1) tensor([7.0352e-02, 8.6557e-01, 2.9562e-05, 6.2988e-02, 1.0582e-03])
#
# 00000155.jpg
# black tensor(0) tensor([9.9909e-01, 7.5869e-04, 4.0444e-05, 1.0464e-04, 1.3730e-06])
#
# 00000037.jpg
# grizzly tensor(1) tensor([8.5869e-05, 9.9979e-01, 2.6621e-07, 1.7600e-07, 1.2330e-04])
#
# 00000121.jpg
# panda tensor(2) tensor([4.1553e-05, 2.2666e-06, 9.9976e-01, 1.3329e-05, 1.7896e-04])
#
# 00000129.jpg
# teddy tensor(4) tensor([0.0049, 0.0020, 0.1822, 0.1263, 0.6846])
#
# 00000057.jpg
# grizzly tensor(1) tensor([1.9343e-04, 9.9879e-01, 2.4366e-06, 8.5755e-04, 1.5697e-04])
#
# 00000059.jpg
# grizzly tensor(1) tensor([8.8965e-02, 7.4551e-01, 7.8643e-07, 1.1746e-01, 4.8066e-02])
#
# 00000181.jpg
# black tensor(0) tensor([6.0608e-01, 1.4128e-03, 3.7667e-01, 1.1926e-04, 1.5721e-02])
#
# 00000167.jpg
# panda tensor(2) tensor([6.1182e-04, 9.7998e-05, 9.9860e-01, 1.0177e-05, 6.7955e-04])
#
# 00000027.jpg
# polar tensor(3) tensor([0.0353, 0.0016, 0.0266, 0.9353, 0.0012])
#
# 00000033.jpg
# teddy tensor(4) tensor([3.4383e-02, 4.0560e-01, 2.5619e-05, 1.4764e-03, 5.5852e-01])
#
# 00000003.jpg
# grizzly tensor(1) tensor([4.9599e-05, 9.7446e-01, 1.3102e-04, 2.5022e-02, 3.3981e-04])
#
# 00000040.jpg
# panda tensor(2) tensor([5.8683e-04, 2.1444e-03, 6.8354e-01, 3.1304e-04, 3.1342e-01])
#
# 00000076.jpg
# grizzly tensor(1) tensor([4.7427e-03, 7.0874e-01, 9.8285e-02, 4.4073e-04, 1.8779e-01])
#
# 00000049.jpg
# polar tensor(3) tensor([3.6167e-11, 2.1678e-11, 1.4102e-13, 1.0000e+00, 2.3803e-10])
#
# 00000012.jpg
# panda tensor(2) tensor([1.8725e-04, 4.4569e-03, 7.0241e-01, 4.6395e-04, 2.9248e-01])
#
# 00000140.jpg
# grizzly tensor(1) tensor([6.3948e-03, 9.9287e-01, 1.1342e-05, 6.9856e-05, 6.5424e-04])
#
# 00000063.jpg
# black tensor(0) tensor([9.9572e-01, 4.2712e-03, 7.2418e-06, 7.2645e-07, 1.6150e-07])
#
# 00000152.jpg
# grizzly tensor(1) tensor([4.6761e-03, 9.8459e-01, 1.6374e-04, 8.8625e-03, 1.7065e-03])
#
# 00000069.jpg
# grizzly tensor(1) tensor([4.2411e-02, 9.0788e-01, 6.8344e-05, 1.2047e-03, 4.8438e-02])
#
# 00000093.jpg
# panda tensor(2) tensor([9.8930e-04, 1.2650e-05, 9.9687e-01, 1.0177e-05, 2.1148e-03])
#
# 00000009.jpg
# grizzly tensor(1) tensor([1.2666e-04, 9.9974e-01, 2.1988e-05, 8.6073e-05, 2.1190e-05])
#
# 00000147.jpg
# teddy tensor(4) tensor([5.2664e-10, 1.0506e-07, 1.2957e-07, 1.7507e-06, 1.0000e+00])
#
# 00000028.jpg
# grizzly tensor(1) tensor([8.0002e-03, 9.8306e-01, 7.0699e-03, 1.1171e-03, 7.4819e-04])
#
# 00000184.jpg
# teddy tensor(4) tensor([6.4479e-05, 9.5352e-04, 3.1646e-04, 1.6717e-05, 9.9865e-01])
#
# 00000019.jpg
# teddy tensor(4) tensor([8.3639e-05, 4.0731e-05, 1.4096e-02, 6.6359e-05, 9.8571e-01])
#
# 00000104.jpg
# black tensor(0) tensor([9.4435e-01, 1.7251e-02, 9.4581e-05, 3.6520e-02, 1.7799e-03])
#
# 00000073.jpg
# grizzly tensor(1) tensor([8.1159e-05, 9.9992e-01, 7.0201e-08, 3.1046e-07, 2.2196e-07])
#
# 00000053.jpg
# grizzly tensor(1) tensor([4.0783e-04, 9.9948e-01, 5.5927e-07, 1.0639e-04, 7.8452e-07])
#
# 00000128.jpg
# black tensor(0) tensor([4.9999e-01, 3.1460e-01, 1.7362e-04, 1.0790e-03, 1.8415e-01])
#
# 00000131.jpg
# grizzly tensor(1) tensor([2.9028e-02, 9.4607e-01, 3.4225e-04, 2.4783e-03, 2.2086e-02])
#
# 00000094.jpg
# grizzly tensor(1) tensor([4.7060e-04, 9.9952e-01, 1.0141e-06, 3.6048e-06, 2.9165e-06])
#
# 00000126.jpg
# panda tensor(2) tensor([4.4992e-03, 9.0839e-04, 6.2821e-01, 1.2451e-04, 3.6626e-01])
#
# 00000010.jpg
# grizzly tensor(1) tensor([1.7308e-05, 9.9640e-01, 1.2399e-07, 3.5790e-03, 4.1210e-06])
#
# 00000139.jpg
# panda tensor(2) tensor([2.7790e-01, 5.6474e-04, 7.2153e-01, 1.8375e-06, 3.5852e-06])
#
# 00000159.jpg
# grizzly tensor(1) tensor([4.5523e-01, 5.4386e-01, 1.1013e-08, 1.2961e-04, 7.8068e-04])
#
# 00000174.jpg
# polar tensor(3) tensor([4.7067e-11, 7.8295e-11, 6.2154e-11, 1.0000e+00, 3.8759e-10])
#
# 00000015.jpg
# grizzly tensor(1) tensor([5.0906e-03, 9.9490e-01, 1.1940e-06, 1.6945e-06, 7.9307e-06])
#
# 00000141.jpg
# black tensor(0) tensor([9.9986e-01, 1.3560e-04, 9.0372e-09, 9.0653e-10, 3.5030e-08])
#
# 00000052.jpg
# grizzly tensor(1) tensor([3.5211e-01, 6.4679e-01, 1.1333e-05, 3.8938e-05, 1.0439e-03])
#
# 00000072.jpg
# grizzly tensor(1) tensor([3.4147e-03, 9.9657e-01, 3.6222e-08, 1.5136e-05, 2.1935e-07])
#
# 00000133.jpg
# teddy tensor(4) tensor([2.9170e-03, 8.7218e-04, 3.7187e-04, 3.2407e-02, 9.6343e-01])
#
# 00000166.jpg
# grizzly tensor(1) tensor([3.2176e-02, 9.6777e-01, 7.8943e-09, 5.2670e-09, 5.7292e-05])
#
# 00000054.jpg
# panda tensor(2) tensor([5.7628e-04, 7.5616e-06, 9.7466e-01, 6.1698e-05, 2.4692e-02])
#
# 00000154.jpg
# grizzly tensor(1) tensor([2.2915e-04, 9.9903e-01, 5.6897e-06, 7.0737e-05, 6.6774e-04])
#
# 00000043.jpg
# grizzly tensor(1) tensor([3.6688e-04, 9.8765e-01, 1.1461e-02, 3.3102e-04, 1.9503e-04])
#
# 00000086.jpg
# teddy tensor(4) tensor([2.2405e-04, 1.2285e-02, 9.2655e-03, 1.0267e-03, 9.7720e-01])
#
# 00000179.jpg
# polar tensor(3) tensor([0.0177, 0.0013, 0.0259, 0.9481, 0.0071])
#
# 00000113.jpg
# grizzly tensor(1) tensor([9.6455e-04, 9.9902e-01, 1.8621e-06, 1.5090e-07, 1.0455e-05])
#
# 00000038.jpg
# grizzly tensor(1) tensor([2.9093e-02, 9.5556e-01, 2.2871e-05, 1.4825e-02, 4.9708e-04])
#
# 00000017.jpg
# black tensor(0) tensor([8.5040e-01, 1.4958e-01, 4.2815e-07, 1.1239e-05, 5.0880e-06])
#
# 00000110.jpg
# grizzly tensor(1) tensor([0.1412, 0.8369, 0.0041, 0.0155, 0.0023])
#
# 00000157.jpg
# panda tensor(2) tensor([1.6398e-03, 2.6057e-05, 9.9592e-01, 3.8785e-06, 2.4057e-03])
#
# 00000137.jpg
# teddy tensor(4) tensor([5.3643e-03, 1.7024e-01, 5.9550e-02, 1.0774e-05, 7.6484e-01])
#
# 00000170.jpg
# grizzly tensor(1) tensor([5.2462e-03, 6.9112e-01, 1.3197e-05, 3.1558e-02, 2.7206e-01])
#
# 00000050.jpg
# grizzly tensor(1) tensor([3.2630e-02, 5.8154e-01, 3.8570e-01, 6.1893e-05, 6.1257e-05])
#
# 00000185.jpg
# panda tensor(2) tensor([0.2525, 0.0070, 0.6616, 0.0008, 0.0781])
#
# 00000194.jpg
# panda tensor(2) tensor([0.0269, 0.0014, 0.6637, 0.2233, 0.0847])
#
# 00000078.jpg
# grizzly tensor(1) tensor([1.5481e-02, 9.8404e-01, 4.3400e-04, 1.5881e-05, 2.9552e-05])
#
# 00000196.jpg
# teddy tensor(4) tensor([1.0438e-02, 1.0513e-02, 7.5253e-02, 1.7399e-04, 9.0362e-01])
#
# 00000109.jpg
# grizzly tensor(1) tensor([4.5628e-03, 9.9255e-01, 1.8631e-05, 2.3097e-03, 5.6354e-04])
#
# 00000158.jpg
# teddy tensor(4) tensor([2.4788e-04, 1.5055e-02, 1.2702e-04, 3.7620e-02, 9.4695e-01])
#
# 00000118.jpg
# polar tensor(3) tensor([2.4817e-08, 2.3887e-07, 2.0315e-06, 9.9986e-01, 1.3761e-04])
#
# 00000107.jpg
# black tensor(0) tensor([0.5246, 0.2492, 0.1613, 0.0345, 0.0304])
#
# 00000120.jpg
# grizzly tensor(1) tensor([4.1789e-04, 9.9814e-01, 1.8192e-05, 1.4072e-03, 2.1474e-05])
#
# 00000117.jpg
# grizzly tensor(1) tensor([2.1141e-04, 9.9778e-01, 5.4425e-07, 1.9408e-03, 6.4530e-05])
#
# 00000153.jpg
# grizzly tensor(1) tensor([1.1326e-02, 9.5990e-01, 2.8362e-02, 3.6879e-04, 4.7968e-05])
#
# 00000044.jpg
# polar tensor(3) tensor([7.1119e-06, 1.7332e-04, 4.8625e-06, 9.9980e-01, 1.0758e-05])
#
# 00000022.jpg
# black tensor(0) tensor([9.3267e-01, 6.2969e-02, 4.5036e-06, 8.6379e-05, 4.2710e-03])
#
# 00000177.jpg
# polar tensor(3) tensor([0.0034, 0.0714, 0.0364, 0.8175, 0.0714])
#
# 00000134.jpg
# panda tensor(2) tensor([3.1779e-04, 1.5491e-05, 9.5860e-01, 5.3309e-04, 4.0532e-02])
#
# 00000150.jpg
# grizzly tensor(1) tensor([1.0605e-01, 8.9179e-01, 1.6792e-03, 4.2380e-04, 5.4636e-05])
#
# 00000062.jpg
# grizzly tensor(1) tensor([0.1122, 0.8448, 0.0053, 0.0023, 0.0354])
#
# 00000198.jpg
# panda tensor(2) tensor([2.0866e-04, 1.5277e-04, 9.9798e-01, 3.5271e-06, 1.6507e-03])
#
# 00000102.jpg
# grizzly tensor(1) tensor([1.1594e-02, 9.8772e-01, 1.7324e-04, 4.3624e-04, 8.1478e-05])
#
# 00000148.jpg
# teddy tensor(4) tensor([0.2124, 0.0078, 0.1456, 0.0360, 0.5982])
#
# 00000080.jpg
# grizzly tensor(1) tensor([3.0695e-01, 6.9233e-01, 2.4164e-06, 4.2622e-04, 2.9597e-04])
#
# 00000031.jpg
# polar tensor(3) tensor([9.4668e-08, 1.2975e-05, 3.6623e-09, 9.9999e-01, 1.8720e-08])
#
# 00000156.jpg
# grizzly tensor(1) tensor([6.2210e-05, 9.9803e-01, 7.9174e-08, 1.8663e-03, 4.5944e-05])
#
# 00000175.jpg
# polar tensor(3) tensor([9.8220e-10, 4.8997e-08, 9.0582e-09, 1.0000e+00, 3.3127e-07])
#
# 00000169.jpg
# grizzly tensor(1) tensor([9.1532e-02, 9.0163e-01, 7.6697e-05, 3.1159e-05, 6.7293e-03])
#
# 00000168.jpg
# polar tensor(3) tensor([0.0029, 0.4199, 0.0075, 0.4788, 0.0910])
#
# 00000077.jpg
# panda tensor(2) tensor([1.1245e-03, 8.8117e-07, 9.9873e-01, 1.9492e-05, 1.2869e-04])
#
# 00000081.jpg
# black tensor(0) tensor([9.9985e-01, 1.0656e-04, 4.7049e-05, 5.4206e-07, 3.0877e-07])
#
# 00000047.jpg
# panda tensor(2) tensor([2.8245e-02, 1.0732e-04, 9.6976e-01, 1.6227e-04, 1.7259e-03])
#
# 00000056.jpg
# grizzly tensor(1) tensor([4.6151e-04, 9.9936e-01, 1.6679e-06, 1.6573e-04, 1.3923e-05])
#
# 00000016.jpg
# panda tensor(2) tensor([9.0144e-06, 1.1004e-04, 9.9988e-01, 1.2012e-06, 1.0672e-06])
#
# 00000143.jpg
# panda tensor(2) tensor([5.4693e-03, 3.2399e-04, 9.9400e-01, 1.7853e-04, 2.3541e-05])
#
# 00000091.jpg
# teddy tensor(4) tensor([1.7957e-05, 8.5557e-05, 1.2868e-03, 1.0140e-04, 9.9851e-01])
#
# 00000199.jpg
# teddy tensor(4) tensor([1.3973e-05, 5.2689e-04, 3.0383e-01, 2.3241e-01, 4.6322e-01])
#
# 00000061.jpg
# teddy tensor(4) tensor([2.1761e-04, 6.8306e-04, 6.5509e-03, 3.8946e-04, 9.9216e-01])
#
# 00000082.jpg
# black tensor(0) tensor([9.2283e-01, 7.7164e-02, 5.8372e-06, 2.7103e-06, 3.3022e-07])
#
# 00000103.jpg
# panda tensor(2) tensor([2.9791e-04, 8.9033e-07, 9.9915e-01, 5.9799e-05, 4.9115e-04])
#
# 00000098.jpg
# panda tensor(2) tensor([3.0881e-02, 2.0491e-05, 9.6725e-01, 1.3181e-05, 1.8384e-03])
#
# 00000055.jpg
# black tensor(0) tensor([9.9979e-01, 2.1260e-04, 9.0206e-07, 2.2010e-08, 8.4671e-07])
#
# 00000013.jpg
# black tensor(0) tensor([9.9994e-01, 5.5131e-05, 5.8129e-08, 2.2324e-08, 8.9070e-09])
#
# 00000018.jpg
# grizzly tensor(1) tensor([1.5899e-04, 9.9955e-01, 4.0901e-05, 1.9822e-04, 4.6980e-05])
#
# 00000132.jpg
# teddy tensor(4) tensor([4.9001e-02, 1.9796e-01, 2.2488e-04, 8.1829e-04, 7.5200e-01])
#
# 00000162.jpg
# teddy tensor(4) tensor([1.5917e-03, 9.1678e-07, 8.9284e-03, 1.4233e-07, 9.8948e-01])
#
# 00000088.jpg
# black tensor(0) tensor([9.9889e-01, 1.0945e-03, 4.9066e-06, 2.6085e-06, 4.2810e-06])
#
# 00000176.jpg
# black tensor(0) tensor([8.9239e-01, 1.0256e-02, 9.7221e-02, 1.2851e-04, 8.8269e-06])
#
# 00000130.jpg
# black tensor(0) tensor([9.5917e-01, 4.0795e-02, 7.9475e-06, 6.5500e-06, 2.0936e-05])
#
# 00000071.jpg
# black tensor(0) tensor([9.7530e-01, 2.4080e-02, 5.9718e-04, 3.2644e-06, 2.1012e-05])
#
# 00000070.jpg
# grizzly tensor(1) tensor([4.3755e-05, 9.9943e-01, 2.8434e-11, 5.2493e-04, 4.7565e-07])
#
# 00000004.jpg
# grizzly tensor(1) tensor([2.0732e-04, 9.9979e-01, 5.2927e-07, 1.8019e-06, 8.0526e-08])
#
# 00000058.jpg
# black tensor(0) tensor([9.2427e-01, 6.3370e-02, 1.2070e-02, 2.2472e-04, 6.5105e-05])
#
# 00000122.jpg
# panda tensor(2) tensor([0.0462, 0.0057, 0.9382, 0.0031, 0.0067])
#
# 00000020.jpg
# grizzly tensor(1) tensor([3.7520e-03, 9.9624e-01, 6.5338e-07, 4.5542e-06, 5.6141e-06])
#
# 00000138.jpg
# panda tensor(2) tensor([0.0228, 0.0748, 0.4173, 0.1731, 0.3120])
#
# 00000099.jpg
# black tensor(0) tensor([9.9691e-01, 3.0509e-03, 3.7734e-05, 1.9182e-06, 7.2052e-07])
#
# 00000145.jpg
# panda tensor(2) tensor([0.0385, 0.0407, 0.8537, 0.0121, 0.0550])
#
# 00000197.jpg
# panda tensor(2) tensor([1.0931e-02, 2.5675e-01, 3.8458e-01, 3.4773e-01, 1.8673e-05])
#
# 00000163.jpg
# grizzly tensor(1) tensor([7.8828e-05, 9.4220e-01, 4.0760e-03, 8.4422e-06, 5.3633e-02])
#
# 00000041.jpg
# grizzly tensor(1) tensor([3.3072e-03, 6.8845e-01, 4.6611e-05, 8.1321e-02, 2.2687e-01])
#
# 00000032.jpg
# grizzly tensor(1) tensor([7.1698e-05, 9.9774e-01, 1.5322e-09, 2.1775e-03, 1.5093e-05])
#
# 00000005.jpg
# grizzly tensor(1) tensor([8.4173e-05, 9.9990e-01, 1.5814e-06, 7.0311e-06, 5.9575e-06])
#
# 00000111.jpg
# black tensor(0) tensor([7.6842e-01, 2.3123e-01, 7.7829e-05, 1.2424e-06, 2.6647e-04])
#
# 00000188.jpg
# black tensor(0) tensor([9.2159e-01, 5.4943e-02, 6.8592e-04, 1.4932e-02, 7.8541e-03])
#
# 00000036.jpg
# grizzly tensor(1) tensor([4.6131e-03, 9.9524e-01, 1.8585e-06, 7.7203e-06, 1.3359e-04])
#
# 00000014.jpg
# grizzly tensor(1) tensor([1.3800e-05, 5.5376e-01, 8.4421e-09, 4.4621e-01, 1.2220e-05])
#
# 00000075.jpg
# grizzly tensor(1) tensor([1.0874e-03, 9.9778e-01, 2.8158e-08, 1.1247e-03, 5.9527e-06])
#
# 00000000.jpg
# grizzly tensor(1) tensor([6.6712e-02, 8.7248e-01, 8.2905e-04, 6.8242e-03, 5.3154e-02])
#
# 00000097.jpg
# grizzly tensor(1) tensor([5.1160e-03, 9.9484e-01, 3.7039e-07, 5.5937e-06, 3.5669e-05])
#
# 00000144.jpg
# grizzly tensor(1) tensor([2.6019e-04, 9.9594e-01, 2.2303e-07, 3.7920e-03, 8.6240e-06])
#
# 00000079.jpg
# panda tensor(2) tensor([6.6672e-02, 1.9655e-05, 9.2988e-01, 6.0011e-05, 3.3671e-03])
#
# 00000146.jpg
# grizzly tensor(1) tensor([9.5278e-05, 9.9990e-01, 3.7853e-08, 1.9876e-06, 3.5322e-06])
#
# 00000115.jpg
# grizzly tensor(1) tensor([9.3254e-03, 9.9065e-01, 9.4558e-07, 1.8171e-05, 7.3632e-06])
#
# 00000108.jpg
# black tensor(0) tensor([9.8951e-01, 9.3315e-03, 1.6539e-05, 2.5951e-05, 1.1153e-03])
#
# 00000195.jpg
# teddy tensor(4) tensor([0.0030, 0.0507, 0.0016, 0.0608, 0.8838])
#
# 00000186.jpg
# grizzly tensor(1) tensor([9.1996e-03, 9.9031e-01, 3.0401e-04, 5.6769e-05, 1.3036e-04])
#
# 00000030.jpg
# black tensor(0) tensor([8.4411e-01, 1.5588e-01, 7.4678e-07, 2.4002e-08, 1.1249e-06])
#
# 00000096.jpg
# black tensor(0) tensor([1.0000e+00, 3.8397e-06, 2.9708e-10, 1.2160e-07, 5.1953e-08])
#
# 00000119.jpg
# teddy tensor(4) tensor([4.3772e-04, 1.5054e-03, 3.5300e-01, 4.4803e-02, 6.0025e-01])
#
# 00000142.jpg
# grizzly tensor(1) tensor([1.2808e-01, 8.5409e-01, 1.4729e-05, 1.7688e-04, 1.7639e-02])
#
# 00000051.jpg
# panda tensor(2) tensor([3.9156e-06, 9.7690e-07, 9.9839e-01, 3.5326e-06, 1.6058e-03])
#
# 00000060.jpg
# black tensor(0) tensor([7.9835e-01, 1.0919e-01, 1.2924e-02, 6.9632e-04, 7.8839e-02])
#
# 00000187.jpg
# teddy tensor(4) tensor([9.3314e-02, 2.4007e-02, 4.0415e-01, 1.5965e-04, 4.7837e-01])
#
# 00000105.jpg
# black tensor(0) tensor([6.6358e-01, 2.5459e-02, 1.7017e-01, 4.8023e-04, 1.4031e-01])
#
# 00000189.jpg
# panda tensor(2) tensor([0.0023, 0.0013, 0.5957, 0.0035, 0.3971])
#
# 00000101.jpg
# grizzly tensor(1) tensor([2.0238e-04, 9.9602e-01, 2.3567e-07, 3.7742e-03, 4.2868e-06])
#
# 00000007.jpg
# grizzly tensor(1) tensor([8.6319e-03, 9.8788e-01, 1.2000e-06, 3.1493e-03, 3.3399e-04])
#
# 00000114.jpg
# grizzly tensor(1) tensor([5.9318e-02, 9.3978e-01, 1.0869e-05, 3.0243e-06, 8.9112e-04])
#
# 00000183.jpg
# teddy tensor(4) tensor([7.3428e-05, 3.2530e-03, 1.4751e-05, 1.9946e-02, 9.7671e-01])
#
# 00000066.jpg
# grizzly tensor(1) tensor([2.2914e-03, 9.9763e-01, 1.1413e-06, 5.5541e-05, 1.7229e-05])
#
# 00000095.jpg
# panda tensor(2) tensor([0.0062, 0.1573, 0.7749, 0.0019, 0.0597])
#
# 00000112.jpg
# teddy tensor(4) tensor([1.3093e-07, 1.1942e-06, 2.3943e-03, 5.0424e-08, 9.9760e-01])
#
# 00000029.jpg
# grizzly tensor(1) tensor([1.5428e-04, 9.9985e-01, 4.6094e-07, 5.0624e-08, 4.2705e-08])
#
# 00000084.jpg
# grizzly tensor(1) tensor([8.8872e-04, 9.9901e-01, 1.6119e-05, 7.0713e-05, 1.6342e-05])
#
# 00000178.jpg
# panda tensor(2) tensor([6.3739e-04, 1.5165e-04, 9.7079e-01, 3.5585e-05, 2.8390e-02])
#
# 00000064.jpg
# grizzly tensor(1) tensor([4.7313e-04, 9.9851e-01, 6.0152e-09, 2.3817e-06, 1.0176e-03])
#
# 00000124.jpg
# black tensor(0) tensor([9.9989e-01, 6.9069e-05, 1.2492e-05, 1.7334e-05, 8.1640e-06])
#
# 00000067.jpg
# panda tensor(2) tensor([2.2499e-03, 2.3398e-04, 7.7432e-01, 1.9719e-01, 2.6005e-02])
#
# 00000046.jpg
# polar tensor(3) tensor([0.0128, 0.3367, 0.0041, 0.6319, 0.0145])
#
# 00000006.jpg
# grizzly tensor(1) tensor([1.2106e-02, 9.4819e-01, 9.8689e-06, 5.0362e-05, 3.9642e-02])
#
# 00000026.jpg
# teddy tensor(4) tensor([6.8172e-03, 3.4963e-01, 7.2120e-05, 1.3827e-01, 5.0521e-01])
#
# 00000085.jpg
# teddy tensor(4) tensor([0.0104, 0.0914, 0.0455, 0.3882, 0.4645])
#
# 00000045.jpg
# panda tensor(2) tensor([1.8571e-04, 2.3146e-07, 9.9895e-01, 1.2104e-05, 8.5693e-04])
#
# 00000090.jpg
# panda tensor(2) tensor([1.1147e-02, 6.5621e-03, 9.7602e-01, 2.9627e-04, 5.9717e-03])
#
# 00000160.jpg
# teddy tensor(4) tensor([1.5131e-06, 2.0463e-07, 1.1355e-01, 2.5526e-05, 8.8643e-01])
#
# 00000106.jpg
# panda tensor(2) tensor([2.2035e-01, 5.1673e-02, 7.0936e-01, 2.1924e-04, 1.8396e-02])
#
# 00000127.jpg
# black tensor(0) tensor([8.8966e-01, 1.0561e-01, 3.7155e-04, 1.6262e-04, 4.1908e-03])
#
# 00000092.jpg
# teddy tensor(4) tensor([1.2038e-04, 3.3731e-05, 1.0584e-01, 1.8640e-06, 8.9400e-01])
#
# 00000192.jpg
# teddy tensor(4) tensor([3.0142e-05, 7.9209e-05, 1.3941e-02, 1.1640e-01, 8.6955e-01])
#
# 00000083.jpg
# teddy tensor(4) tensor([1.2602e-05, 1.0211e-05, 4.6985e-04, 5.1813e-06, 9.9950e-01])
#
# 00000165.jpg
# grizzly tensor(1) tensor([3.8907e-01, 4.7425e-01, 7.9148e-02, 1.8048e-05, 5.7516e-02])
#
# 00000048.jpg
# black tensor(0) tensor([9.9827e-01, 1.7233e-03, 3.4191e-07, 1.5091e-06, 6.3089e-07])
#
# 00000011.jpg
# grizzly tensor(1) tensor([1.3683e-02, 9.8616e-01, 3.5333e-05, 1.2135e-06, 1.2554e-04])
#
# 00000172.jpg
# black tensor(0) tensor([9.9887e-01, 1.0851e-03, 1.1730e-06, 1.0092e-07, 4.0880e-05])
#
# 00000024.jpg
# black tensor(0) tensor([9.4544e-01, 5.5764e-03, 4.4836e-02, 4.0781e-03, 6.9045e-05])
#
# 00000180.jpg
# grizzly tensor(1) tensor([2.7649e-02, 9.7035e-01, 3.6693e-06, 1.9705e-03, 2.2322e-05])
#
# 00000087.jpg
# panda tensor(2) tensor([2.4425e-02, 2.1699e-03, 9.5773e-01, 6.7664e-04, 1.4997e-02])
#
# 00000135.jpg
# teddy tensor(4) tensor([3.2398e-06, 2.3703e-05, 1.4809e-02, 8.0167e-06, 9.8516e-01])
#
# 00000034.jpg
# teddy tensor(4) tensor([1.3855e-04, 1.0785e-06, 1.1455e-01, 1.7357e-04, 8.8514e-01])
#
# 00000173.jpg
# grizzly tensor(1) tensor([3.6448e-04, 9.9963e-01, 4.9212e-08, 1.4746e-06, 1.8210e-06])
#
# 00000164.jpg
# black tensor(0) tensor([1.0000e+00, 8.3764e-08, 8.0639e-07, 1.6349e-10, 1.1064e-09])
#
# 00000191.jpg
# panda tensor(2) tensor([0.0009, 0.0021, 0.9228, 0.0281, 0.0460])
#
# 00000039.jpg
# panda tensor(2) tensor([2.8941e-03, 2.0534e-04, 9.3791e-01, 5.3798e-04, 5.8457e-02])
#
# 00000035.jpg
# grizzly tensor(1) tensor([3.7681e-05, 9.9973e-01, 1.0756e-08, 2.2767e-04, 1.4940e-07])
#
# 00000025.jpg
# grizzly tensor(1) tensor([1.9034e-04, 9.9970e-01, 2.0659e-07, 1.0321e-04, 7.0408e-06])
#
# 00000023.jpg
# grizzly tensor(1) tensor([2.7671e-03, 9.9644e-01, 8.0427e-07, 7.8450e-04, 1.1931e-05])
#
# 00000002.jpg
# grizzly tensor(1) tensor([5.6918e-03, 9.8988e-01, 2.0530e-05, 1.4584e-03, 2.9470e-03])
#
# 00000171.jpg
# grizzly tensor(1) tensor([5.9771e-04, 9.9896e-01, 3.7555e-05, 3.7284e-04, 2.7922e-05])
